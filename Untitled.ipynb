# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
from tqdm.auto import tqdm
import concurrent.futures
from multiprocessing import Pool
import copy,os,sys,psutil
from collections import Counter

# %%
import pandas as pd

# %%
df_chunks = pd.read_csv("/home/zhoutong/uidCnt.csv")
df_chunks.sort_values(by="count", ascending=False, inplace=True)
df_chunks
# Out:
#             uid_s   count
# 468           NaN  961657
# 469        6453.0    1961
# 470        8222.0     809
# 471        9985.0     635
# 472        6899.0     631
# ...           ...     ...
# 11157  24029918.0       1
# 11158  23184523.0       1
# 11159  17410920.0       1
# 11160  23069750.0       1
# 9524      11589.0       1
#
# [19049 rows x 2 columns]

# %% [markdown]
# DBSCAN做异常检测

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=10, min_samples=20)
sample = np.array(df_chunks.query("count>1")['count']).reshape(-1,1)
_ = dbscan.fit_predict(sample)
# 对于DBSCAN来说，两个最重要的参数就是eps，和min_samples。当然这两个值不是随便定义的，这个在下文再说
np.unique(dbscan.labels_,return_counts=True)
# Out:
# (array([-1,  0]), array([   74, 12058]))

# %%
[i for i in np.concatenate([sample, dbscan.labels_.reshape(-1,1)],axis=1) if i[1] in [-1,0,1,2,3]]

np.unique(dbscan.labels_,return_counts=True)
dbscan.components_.shape
# Out:
# [array([961657,     -1]),
#  array([1961,   -1]),
#  array([809,  -1]),
#  array([635,  -1]),
#  array([631,  -1]),
#  array([528,  -1]),
#  array([505,  -1]),
#  array([503,  -1]),
#  array([482,  -1]),
#  array([437,  -1]),
#  array([381,  -1]),
#  array([375,  -1]),
#  array([341,  -1]),
#  array([316,  -1]),
#  array([310,  -1]),
#  array([309,  -1]),
#  array([299,  -1]),
#  array([296,  -1]),
#  array([273,  -1]),
#  array([270,  -1]),
#  array([269,  -1]),
#  array([268,  -1]),
#  array([265,  -1]),
#  array([245,  -1]),
#  array([233,  -1]),
#  array([226,  -1]),
#  array([223,  -1]),
#  array([219,  -1]),
#  array([216,  -1]),
#  array([208,  -1]),
#  array([197,  -1]),
#  array([193,  -1]),
#  array([186,  -1]),
#  array([185,  -1]),
#  array([183,  -1]),
#  array([181,  -1]),
#  array([180,  -1]),
#  array([171,  -1]),
#  array([170,  -1]),
#  array([166,  -1]),
#  array([165,  -1]),
#  array([162,  -1]),
#  array([162,  -1]),
#  array([159,  -1]),
#  array([158,  -1]),
#  array([155,  -1]),
#  array([153,  -1]),
#  array([152,  -1]),
#  array([152,  -1]),
#  array([149,  -1]),
#  array([147,  -1]),
#  array([145,  -1]),
#  array([141,  -1]),
#  array([140,  -1]),
#  array([134,  -1]),
#  array([133,  -1]),
#  array([132,  -1]),
#  array([127,  -1]),
#  array([125,  -1]),
#  array([119,  -1]),
#  array([119,  -1]),
#  array([118,  -1]),
#  array([118,  -1]),
#  array([117,  -1]),
#  array([117,  -1]),
#  array([115,  -1]),
#  array([113,  -1]),
#  array([113,  -1]),
#  array([109,  -1]),
#  array([109,  -1]),
#  array([107,  -1]),
#  array([106,  -1]),
#  array([105,  -1]),
#  array([101,  -1]),
#  array([98,  0]),
#  array([98,  0]),
#  array([95,  0]),
#  array([95,  0]),
#  array([95,  0]),
#  array([93,  0]),
#  array([92,  0]),
#  array([90,  0]),
#  array([89,  0]),
#  array([88,  0]),
#  array([88,  0]),
#  array([88,  0]),
#  array([88,  0]),
#  array([85,  0]),
#  array([85,  0]),
#  array([84,  0]),
#  array([83,  0]),
#  array([83,  0]),
#  array([79,  0]),
#  array([79,  0]),
#  array([77,  0]),
#  array([76,  0]),
#  array([74,  0]),
#  array([74,  0]),
#  array([74,  0]),
#  array([73,  0]),
#  array([73,  0]),
#  array([72,  0]),
#  array([72,  0]),
#  array([72,  0]),
#  array([70,  0]),
#  array([68,  0]),
#  array([67,  0]),
#  array([66,  0]),
#  array([66,  0]),
#  array([65,  0]),
#  array([65,  0]),
#  array([61,  0]),
#  array([61,  0]),
#  array([60,  0]),
#  array([60,  0]),
#  array([59,  0]),
#  array([59,  0]),
#  array([59,  0]),
#  array([58,  0]),
#  array([58,  0]),
#  array([58,  0]),
#  array([57,  0]),
#  array([56,  0]),
#  array([56,  0]),
#  array([56,  0]),
#  array([56,  0]),
#  array([56,  0]),
#  array([55,  0]),
#  array([55,  0]),
#  array([55,  0]),
#  array([54,  0]),
#  array([53,  0]),
#  array([53,  0]),
#  array([53,  0]),
#  array([53,  0]),
#  array([52,  0]),
#  array([52,  0]),
#  array([51,  0]),
#  array([51,  0]),
#  array([50,  0]),
#  array([50,  0]),
#  array([50,  0]),
#  array([49,  0]),
#  array([49,  0]),
#  array([49,  0]),
#  array([49,  0]),
#  array([48,  0]),
#  array([48,  0]),
#  array([48,  0]),
#  array([48,  0]),
#  array([48,  0]),
#  array([47,  0]),
#  array([47,  0]),
#  array([47,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([46,  0]),
#  array([45,  0]),
#  array([45,  0]),
#  array([45,  0]),
#  array([45,  0]),
#  array([45,  0]),
#  array([45,  0]),
#  array([44,  0]),
#  array([44,  0]),
#  array([44,  0]),
#  array([43,  0]),
#  array([42,  0]),
#  array([42,  0]),
#  array([42,  0]),
#  array([42,  0]),
#  array([42,  0]),
#  array([42,  0]),
#  array([41,  0]),
#  array([41,  0]),
#  array([41,  0]),
#  array([41,  0]),
#  array([41,  0]),
#  array([41,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([40,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([39,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([38,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([37,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([36,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([35,  0]),
#  array([34,  0]),
#  array([34,  0]),
#  array([34,  0]),
#  array([34,  0]),
#  array([34,  0]),
#  array([34,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([33,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([32,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([31,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([30,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([29,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([28,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([27,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([26,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([25,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([24,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([23,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([22,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([21,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([20,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([19,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([18,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([17,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([16,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  array([15,  0]),
#  ...]
# (array([-1,  0]), array([   74, 12058]))
# (12047, 1)

# %% [markdown]
# 孤立森林做异常检测

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd

clf = IsolationForest(behaviour='new',max_samples=100, random_state=42)
table = np.array(df_chunks['count']).reshape(-1,1)
clf.fit(table)
pred = clf.predict(table)
predDF=pd.DataFrame(np.concatenate([table,pred.reshape(-1,1)], axis=1), columns=['count','isolation'])
predDF
predDF.query("isolation==-1")
predDF.query("isolation==1")
# Out:
# /home/zhoutong/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:237: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# IsolationForest(behaviour='new', bootstrap=False, contamination='legacy',
#                 max_features=1.0, max_samples=100, n_estimators=100,
#                 n_jobs=None, random_state=42, verbose=0, warm_start=False)
#         count  isolation
# 0      961657         -1
# 1        1961         -1
# 2         809         -1
# 3         635         -1
# 4         631         -1
# ...       ...        ...
# 19044       1          1
# 19045       1          1
# 19046       1          1
# 19047       1          1
# 19048       1          1
#
# [19049 rows x 2 columns]
#        count  isolation
# 0     961657         -1
# 1       1961         -1
# 2        809         -1
# 3        635         -1
# 4        631         -1
# ...      ...        ...
# 1885      10         -1
# 1886      10         -1
# 1887      10         -1
# 1888      10         -1
# 1889      10         -1
#
# [1890 rows x 2 columns]
#        count  isolation
# 1890       9          1
# 1891       9          1
# 1892       9          1
# 1893       9          1
# 1894       9          1
# ...      ...        ...
# 19044      1          1
# 19045      1          1
# 19046      1          1
# 19047      1          1
# 19048      1          1
#
# [17159 rows x 2 columns]
